# %% [raw]
# ---
# title: "Overview"
# format:
#     html:
#         code-fold: true
# jupyter: python3
# fontsize: 1.2em
# linestretch: 1.5
# toc: true
# notebook-view: true
# ---

# %% [markdown]
# This course comprises three distinct but overlapping modules:
#
# - Incompressible fluid mechanics
# - Thermodynamics
# - Compressible fluid mechanics
#
# This course has three papers. It also has a series of example papers that students are encouraged to attempt. Problems from these example papers will be discussed during the recitation session.

# %% [markdown]
# ## Grading
#
# This course has three papers, a final exam, and a coding assignment. The grades are given below:
#
#
# | Assignment  | Grade percentage (%)    |
# | --------  | ------- |
# | Paper 1: Incompressible fluid mechanics    | 20 |
# | Paper 2: Thermodynamics   | 20    |
# | Paper 3: Compressible fluid mechanics   | 20    |
# | Coding assignment   | 15    |
# | Final exam   | 25    |

# %% [markdown]
# ## Lectures
#
# This is a preliminary schedule; it may change throughout term. The suggested readings below are completely optional. The slide decks provided below are partially complete; it is the student's responsibility to attend lectures and complete these slides. That said, as time goes on, incomplete notes will be swapped with complete decks.
#
# ### Incompressible fluid mechanics
#
# 08.23: **L1. Course introduction** | <a href="https://gtvault-my.sharepoint.com/:b:/g/personal/pseshadri34_gatech_edu/EYb4zSH_E2VGq0JReia6Ii4BcBkkqoiSz8b_HdjjVB014g" target="_blank">Slides</a> | <a href="demo.html">Notebook</a>
# <details>
#   <summary>Contents</summary>
#
#   1. Difference between fluid mechanics and thermodynamics.
#   2. Properties of fluids vs solids.
#   3. Forces in fluids.
#   4. Brief introduction to Jupyter notebooks (covering ``python`` and ``latex``).
# </details>
#
#
# 08.25: **L2. Fluid statics (or hydrostatics)** | <a href="https://gtvault-my.sharepoint.com/:b:/g/personal/pseshadri34_gatech_edu/EbjwOq2QaOhLvo3iLGuiioYBsr4_fCcBbq1kI1hk6rzh1w" target="_blank">Slides</a> | <a href="sample_problems/lecture_2.html">Examples</a>
# <details>
#   <summary>Contents</summary>
#
#   1. Basic equations
#   2. Pressure as a function of depth.
#   3. Barometers and manometers.
#   4. Forces on submerged bodies.
#   5. Buoyancy and Archimedes' principle.
# </details>
#
# 08.30: **L3. Control volumes & conservation of mass** | <a href="https://gtvault-my.sharepoint.com/:b:/g/personal/pseshadri34_gatech_edu/EZn7ailuaTJHpd-3bTB3uwABC0jzRqx2NYqXFES9gZqHRg" target="_blank">Slides</a> | <a href="sample_problems/lecture_3.html">Examples</a>
# <details>
#   <summary>Contents</summary>
#
#   1. Fluid dynamics terminology (streamlines, streaklines, pathlines, stagnation).
#   2. Systems and conservation principles.
#   3. Control volumes.
#   4. Conservation of mass.
#   5. In-class application.
# </details>
#
#
# 09.01: **L4. Conservation of momentum** <a href="https://gtvault-my.sharepoint.com/:b:/g/personal/pseshadri34_gatech_edu/ERGp2hzs-lBPgdJ4azziBbIBQGT3B8rGMG_yl-y_gyDTYQ" target="_blank">Slides</a> | <a href="sample_problems/lecture_4.html">Examples</a>
# <details>
#   <summary>Contents</summary>
#
#   1. Newton's second law.
#   2. Steady flow momentum equation in 1D.
#   3. Steady flow momentum equation in 2D.
#
# </details>
#
#
#
# 09.06: **L5. Bernoulli's equation** | <a href="https://gtvault-my.sharepoint.com/:b:/g/personal/pseshadri34_gatech_edu/EYb4zSH_E2VGq0JReia6Ii4BcBkkqoiSz8b_HdjjVB014g" target="_blank">Slides</a> | <a href="demo.html">Notebook</a>
# <details>
#   <summary>Contents</summary>
#
#   1. Forces on fluid particles.
#   2. Acceleration of a fluid particle.
#   3. Forces and acceleration along streamlines.
#   4. Deriving Bernoulli's equation
#   5. Understanding a pitot tube and other devices.
#
# </details>
#
#
# 09.08: **L6. Curved streamlines**
# <details>
#   <summary>Contents</summary>
#
#   1. Conda effect.
#   2. Magnus effect.
#   3. Circulation and lift.
#   4. In-class application.
#
# </details>
#
#
# 09.13: **L7. Velocity vectors**
# <details>
#   <summary>Contents</summary>
#
#   1. Scalar and vector fields (and their derivatives).
#   2. Velocity vectors - divergence and curl.
#   3. Sources and sinks.
#   4. Advection.
#   5. In-class application.
#
# </details>
#
# 09.15: **L8. Couette and Poiseuille flow**
# <details>
#   <summary>Contents</summary>
#
#   1. Viscous flow between parallel plates
#   2. Couette flow
#   3. Poiseuille flow
#   4. Combined Couette and Poiseuille flow
#   5. Euler and Navier-Stokes equations
#
# </details>
#
# 09.15: **L9. Pressure losses**
# <details>
#   <summary>Contents</summary>
#
#   1. Three pressures
#   2. Viscous pipe flow
#   3. Loss of pressure along a pipe
#   4. Practical problems involving pipes
#   5. Engineering units
#
# </details>
#
#
# 09.22: **L10. Incompressible fluid mechanics review**
#
# 09.27: **L11. Paper I**

# %% [markdown]
# ### Thermodynamics
#
#
# 09.29: **L12. Thermodynamics: Introduction and the first law**
# <details>
#   <summary>Contents</summary>
#
#   1. Overview of thermodynamics.
#   2. Molecular thermodynamics vs. classical thermodynamics.
#   3. Properties, systems, and states.
#   4. Thermodynamic equlibrium and the two-property rule.
#   5. Definition of work, heat, and energy.
#   6. General statement of the first law.
#   7. Cyclic processes, adiabatic processes.
# </details>
#
#
# 10.04: **L13. Ideal gases and the first law again**
# <details>
#   <summary>Contents</summary>
#
#   1. Pure substances and phases.
#   2. Enthalpy and specific heat.
#   3. Ideal gas relations.
#   4. Isobaric, isochoric, and isothermal processes.
#   5. Adiabatic compression.
#   6. Polytropic process.
# </details>
#
#
# 10.06: **L14. The second law**
# <details>
#   <summary>Contents</summary>
#
#   1. Reversible and irreversible processes.
#   2. The Kelvin-Planck and Clausius statements.
#   3. Heat engines, refrigerators, and pumps.
#   4. Cycle efficiency and coefficient of performance.
#   5. Carnot cycle.
# </details>
#
# 10.11: **L15. The zeroth law and temperature**
# <details>
#   <summary>Contents</summary>
#
#   1. The zeroth law.
#   2. Empirical temperature scales.
#   3. Thermodynamic temperature and its measurement.
#   4. Sample problems
# </details>
#
# 10.13: **L16. Entropy**
# <details>
#   <summary>Contents</summary>
#
#   1. Revisiting the first two laws.
#   2. The Clausius inequality.
#   3. Definition of entropy.
#   4. Entropy variations for reversible and irreversible processes.
#   5. Sample problems
# </details>
#
# 10.18: **L17. Entropy (again) and mass conservation**
# <details>
#   <summary>Contents</summary>
#
#   1. The Tds equations and entropy of a perfect gas.
#   2. Entropy changes of isolated systems.
#   3. Molecular interpretation of entropy.
#   4. Conservation of mass.
#   5. First Law applied to control volumes.
# </details>
#
# 10.20: **L18. Steady flow energy equation**
# <details>
#   <summary>Contents</summary>
#
#   1. The steady flow energy equation.
#   2. Throttling processes; compressors and turbines.
#   3. Entropy changes for flow processes.
#   4. Steady reversible and irreversible flow.
#   5. Isentropic flow.
#   6. Sample problem.
# </details>
#
#
# 10.25: **L19. Thermodynamics review**
#
#
# 10.27: **L20. Paper II**
#
# 10.28: *Withdrawal deadline*

# %% [markdown]
# ### Compressible fluid mechanics
#
#
# 11.01: **L21. Variable nozzle flows**
# <details>
#   <summary>Contents</summary>
#
#   1. Flow through a converging diverging passage.
#   2. Speed of sound.
#   3. Choked flow.
#   4. Introduction to shock waves.
#   5. Review of coding assignment.
#
# </details>
#
# 11.03: **L22. Normal shocks**
# <details>
#   <summary>Contents</summary>
#
#   1. Flow through a converging diverging passage (again).
#   2. Normal shock identities.
#   3. Problems with normal shocks.
# </details>
#
# 11.08: **L23. Oblique shocks**
# <details>
#   <summary>Contents</summary>
#
#   1. Oblique waves.
#   2. Concave vs. convex corners.
#   3. Wave angles.
#   4. Problems with oblique shocks.
# </details>
#
# 11.10: **L24. Compressible flows with friction**
# <details>
#   <summary>Contents</summary>
#
#   1. Oblique waves.
#   2. Concave vs. convex corners.
#   3. Wave angles.
#   4. Problems with oblique shocks.
# </details>
#
#
# 11.15: **L25. Compressible flows review**
#
# 11.17: **L26. Paper III**
#
# 11.29: **L27. Finals preparation**
#
# 12.01: **L28. Finals preparation**

# %% [markdown]
# ## Lectures and Recitation sessions
#
# Lectures will be held at:
#
# | Location  | Time    |
# | --------  | ------- |
# | GU 442    | Wednesday 8:25am - 10:20am   |
# | GU 442    | Friday 8:25am - 10:20am     |
#
# Recitation sessions will be held at:
#
# | Location  | Time    |
# | --------  | ------- |
# | GU 442    | Wednesday 6:30pm - 7:45pm   |

# %% [markdown]
# ## Office hours
#
# Professor Seshadri's office hours:
#
# | Location  | Time    |
# | --------  | ------- |
# | GU 341    | Monday 3pm - 5pm    |
# | GU 341    | Friday 4pm - 6pm    |
#
# Location may change during term.
#
# UTA John Stafford's office hours are:
#
#
# | Location  | Time    |
# | --------  | ------- |
# | Lowey Library MK 3rd floor    | Monday 10:30am - 12:00 pm |

# %% [markdown]
# ## ED Dashboard
#
# Given that the registration comprises two different courses (2010 & 2011), I will do my best to communicate the threads between them. The links below should take you to the dashboards.
#
# <a href="https://edstem.org/us/courses/44552/discussion/">2010</a>  | <a href="https://edstem.org/us/courses/44554/discussion/">2011</a>

# %% [markdown]
# ## References
#
# The material in this course follows a similar trajectory to other courses, detailed below:
#
# - Engineering Tripos Part 1A (Cambridge)
# - Engineering Tripos Part 2A (Cambridge)
# - Engineering Tripos Part 3A (Cambridge)
# - Course 16 Unified Thermodynamics and Propulsion (MIT)
# - Prior AE2010/AE2011 Notes (Georgia Tech)

# %% [markdown]
# ## Useful textbooks
#
# Although not mandatory, below you will find a list of useful textbooks for this course.
#
# - John Anderson, (2023) *Fundamentals of Aerodyanmics*, Seventh Edition, McGraw-Hill.
# - Michael Boles and Yunus Çengel, (2010) *Thermodynamics: An Engineering Approach*, McGraw-Hill.
# - Snorri Gudmundsson, (2013) *General Aviation Aircraft Design*, Butterworth-Heinemann.
