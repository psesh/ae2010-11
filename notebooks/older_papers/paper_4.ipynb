# %% [raw]
# ---
# title: "Final paper"
# format:
#   pdf:
#     documentclass: report
#     classoption: [twocolumn, landscape]
#     lof: false
#     lot: false
#     geometry:
#       - top=30mm
#       - left=20mm
#       - heightrounded
#     fontfamily: libertinus
#     colorlinks: true
# ---

# %% [markdown]
# # Final paper
# ## Fall 2023 | AE2010-AE2011
# ## Name:
# ### Due Date: Wednesday, December 13th 10:50
# ### Submission location: MK421A

# %% [markdown]
# #### Instructions and comments:
# This is a take-home exam, and should take you less than 115 minutes to complete. While you may discuss questions with other students in this course, the work you submit must be your own. You are welcome to all resources that have been made available on the course website; you will not need any other resources. You are not permitted to post / ask questions on any external online forum; you are also not permitted to speak to any tutor about these questions. Any violation of the above will result in a zero-point grade. Should you have any questions or require any clarifications, please email me. Please do not turn in any scratch paper, and ensure your submitted answers do indeed answer the question that is being asked. Carefully read each question as the ask may be slightly different from questions you have practiced before. The numerical value after each question, e.g., ${\color[rgb]{0.028509,0.250925,0.501969}[5]}$ denotes the number of marks assigned to that question. Finally, please either (i) write down all your answers on a print out of this set, or (ii) write the answers on a separate sheets---the choice is yours. Submit this to my office (MK421A) anytime before the deadline. If I am not in, please slide your solution under the door. No late solutions will be accepted. I wish you all the very best of luck, and I just want to say that it has been a pleasure to be your instructor for this course.

# %% [markdown]
# ### Problem 1
# An air compressor operates in steady flow with air entering with pressure ${\color[rgb]{0.315209,0.728565,0.037706}p_1}$ and temperature ${\color[rgb]{0.164799,0.878862,0.723179}T_1}$, and leaving at pressure ${\color[rgb]{0.315209,0.728565,0.037706}p_2}$. Within the compressor the air undergoes a reversible polytropic process, ${\color[rgb]{0.315209,0.728565,0.037706}p}{\color[rgb]{0.918231,0.469102,0.038229}\nu}^{n} = constant$, where ${\color[rgb]{0.918231,0.469102,0.038229}\nu}$ is the specific volume and $n$ is a constant. Assume air behaves as a perfect gas and neglect changes in kinetic and potential energy between the inlet and outlet.
#
# \begin{enumerate}
# \item[a.] Starting from the expression ${\color[rgb]{0.562040,0.190215,0.568721}dw_{x}} = - {\color[rgb]{0.918231,0.469102,0.038229}\nu}{\color[rgb]{0.315209,0.728565,0.037706}dp}$ for reversible steady flow, show that ${\color[rgb]{0.562040,0.190215,0.568721}w_{x}}$, the shaft work transfer from the compressor per unit mass of air, is given by
#
# \begin{equation*}
# {\color[rgb]{0.562040,0.190215,0.568721}w_x} = - \frac{nR}{n - 1} \left({\color[rgb]{0.164799,0.878862,0.723179}T_2} - {\color[rgb]{0.164799,0.878862,0.723179}T_1} \right),
# \end{equation*}
#
# where $R$ is the gas constant per unit mass of air, i.e., $R = {\color[rgb]{0.315209,0.728565,0.037706}p} {\color[rgb]{0.918231,0.469102,0.038229}\nu} / {\color[rgb]{0.164799,0.878862,0.723179}T}$. ${\color[rgb]{0.028509,0.250925,0.501969}[4]}$
#
#
# {\color{RubineRed}
#
# Given that $dw_{x} = - \nu dp$, the work can be found through integration, i.e., $w_{x} = \int_{1}^{2} \nu dp$. Since $p \nu^{n} = constant$, then $\nu = constant^{1/n} p^{-1/n}$. Substituting this into the work relation yields
#
# \begin{equation*}
# \begin{split}
# w_{x} = -\int_{1}^{2} constant^{1/n} p^{-1/n} dp  = - \left[ constant^{1/n} \frac{1}{1 - \frac{1}{n}} p^{1 - \frac{1}{n}}\right]_{1}^{2} \\
# w_{x} = - \left[ \frac{n}{n-1} p^{1} constant^{\frac{1}{n}} p^{-\frac{1}{n}}\right]_{1}^{2} \\
# w_{x} = - \frac{n}{n-1} \left[ p \nu \right]_{1}^{2} = - \frac{n}{n-1}\left(p_2 \nu_2 - p_1 \nu_1 \right)
# \end{split}
# \end{equation*}
#
# To remove the dependency on pressure, we use the ideal gas equation, i.e., $p \nu = RT$. This results in
#
# \begin{equation*}
# w_{x} = - \frac{n}{n-1} \left( RT_2 - RT_1 \right) = - \frac{nR}{n-1} \left(T_2 - T_1 \right)
# \end{equation*}
#
# }
#
# \item[b.] Derive an expression for the heat transfer to the compressor per unit mass of air in terms of $R, {\color[rgb]{0.164799,0.878862,0.723179}T_1}, {\color[rgb]{0.164799,0.878862,0.723179}T_2}, n$ and the ratio of the specific heat capacities $\gamma$. ${\color[rgb]{0.028509,0.250925,0.501969}[6]}$
#
# {\color{RubineRed}
#
# The steady flow energy equation is given by
#
# \begin{equation*}
# q - w_{x} = \left(h_2 - \frac{v_2^2}{2} + gz_2 \right) - \left(h_1 - \frac{v_1^2}{2} + gz_1 \right),
# \end{equation*}
#
# with no kinetic or potential energy changes this yields
#
# \begin{equation*}
# q - w_{x} = h_2 - h_1  \Rightarrow dh_{1-2} = c_p \left( T_2 - T_1 \right)
# \end{equation*}
#
# From the definitions for $R$ and $\gamma$, we have $R = c_p - c_v$ and $\gamma = c_p / c_v$. This leads to $c_v = c_p / \gamma$ and therefore $R = c_p - c_p/\gamma$.
#
# \begin{equation*}
# R = c_p \left( 1 - \frac{1}{\gamma} \right) \Rightarrow c_p = \frac{R}{1 - \frac{1}{\gamma}} = \frac{\gamma R}{\gamma - 1}
# \end{equation*}
#
# Plugging this expression into the steady flow energy equation along with the result from part (a) results in
#
# \begin{equation*}
# \begin{split}
# q = w_{x} + c_p \left(T_2 - T_1 \right) = - \frac{nR}{n-1} \left(T_2 - T_1 \right) + \frac{\gamma R}{\gamma - 1} \left( T_2 - T_1 \right) \\
# = \left( \frac{\gamma}{\gamma - 1} - \frac{n}{n-1} \right) R \left(T_2 - T_1 \right) \\
# = \left( \frac{\gamma \left( n -1 \right) - n \left( \gamma - 1 \right)}{\left(\gamma - 1 \right) \left( n - 1\right) } \right) R \left(T_2 - T_1 \right)\\
# = \left( \frac{\gamma n - \gamma - n \gamma + n}{\left(\gamma - 1 \right) \left( n - 1\right)} \right) R \left(T_2 - T_1 \right) \\
# = \left( \frac{n - \gamma}{\left(\gamma - 1 \right) \left( n - 1\right)} \right) R \left(T_2 - T_1 \right)
# \end{split}
# \end{equation*}
# }
# \end{enumerate}

# %% [markdown]
# ### Problem 3
# Fluid flows through a duct of height $h$ as shown in the figure below. Part of the upstream section of this duct is divided into two separate ducts of height ${\color[rgb]{0.599997,0.600015,0.600005}h}$ and ${\color[rgb]{0.599997,0.600015,0.600005}3h}$ respectively. At station ${\color[rgb]{0.986252,0.007236,0.027423}1}$, far upstream, the velocity and pressure are uniform in each duct. In the larger duct, the velocity is ${\color[rgb]{0.059472,0.501943,0.998465}v_1}$ and the pressure is ${\color[rgb]{0.315209,0.728565,0.037706}p_1}$, and in the smaller duct the velocity is ${\color[rgb]{0.059472,0.501943,0.998465}9v_1}$, but the pressure is the same.
#
# At some distance from the exit of the smaller duct, a flat plate of height ${\color[rgb]{0.599997,0.600015,0.600005}h}$ is mounted on the floor, perpendicular to the flow. Fluid from the two upstream ducts mixes turbulently and passes through the gap between this flat plate and the top of the duct. At station ${\color[rgb]{0.986252,0.007236,0.027423}2}$, just upstream of the gap, the pressure is uniform across the whole height of the duct and the velocity ${\color[rgb]{0.059472,0.501943,0.998465}v_2}$ is uniform across the gap. At station ${\color[rgb]{0.986252,0.007236,0.027423}3}$, far downstream, the velocity ${\color[rgb]{0.059472,0.501943,0.998465}v_3}$ and pressure ${\color[rgb]{0.315209,0.728565,0.037706}p_3}$ are both uniform over the whole duct height. The fluid throughout has a uniform density of ${\color[rgb]{0.918231,0.469102,0.038229}\rho}$, the flow is incompressible and friction forces may be ignored. The duct has unit width into the page.
#
# \begin{figure}[h]
#     \centering
#     \includegraphics[width=0.4\textwidth]{images/image_P5_1.png}
# \caption{Flow through a duct.}
#     \label{fig:enter-label}
# \end{figure}
#
# \begin{enumerate}
# \item[a.] What is the velocity ${\color[rgb]{0.059472,0.501943,0.998465}v_2}$ in the gap between the plate and the top of the duct in terms of ${\color[rgb]{0.059472,0.501943,0.998465}v_1}$? ${\color[rgb]{0.028509,0.250925,0.501969}[3]}$
#
# {\color{RubineRed}
#
# Applying continuity between stations 1 and 2 we have
#
# \begin{equation*}
# 9 v_1 + v_1 3 h = v_2 3 h \Rightarrow v_2 = 4 v_1
# \end{equation*}
#
# }
#
# \item[b.] What is the velocity ${\color[rgb]{0.059472,0.501943,0.998465}v_3}$ at the station far downstream in terms of ${\color[rgb]{0.059472,0.501943,0.998465}v_1}$? ${\color[rgb]{0.028509,0.250925,0.501969}[3]}$
#
# {\color{RubineRed}
#
# Applying continuity again between station 1 and 3, we have
#
# \begin{equation*}
# 9 v_1 h + v_1 3 h = v_3 4 h \Rightarrow v_3 = 3 v_1
# \end{equation*}
#
#
# }
#
# \item[c.] What is the pressure ${\color[rgb]{0.315209,0.728565,0.037706}p_2}$ at station ${\color[rgb]{0.986252,0.007236,0.027423}2}$ in terms of ${\color[rgb]{0.315209,0.728565,0.037706}p_1}$, ${\color[rgb]{0.918231,0.469102,0.038229}\rho}$, and ${\color[rgb]{0.059472,0.501943,0.998465}v_1}$? ${\color[rgb]{0.028509,0.250925,0.501969}[5]}$
#
# {\color{RubineRed}
#
# Now we apply the steady flow momentum equation for a control volume between stations 1 and 2. The forces are due to the pressures acting on the faces of the control volume, leading to:
#
# \begin{equation*}
# \begin{split}
# p_1 3 h + p_1 h - p_2 4h & = \rho v_2^2 3h - \left( \rho v_1^2 3 h + \rho \left( 9 v_1 \right)^2 h \right) \\
# \Rightarrow 4 p_1 h - 4 p_2 h & = \rho 16 v_1^2 3h - \rho v_1^2 3 h - \rho 81 v_1^2 h = -36 \rho v_1^2 \\
# \Rightarrow p_2 = p_1 + 9 \rho v_1^2
# \end{split}
# \end{equation*}
#
# }
#
# \item[d.] Find an expression for the force $F$ that the plate exerts on the fluid in terms of ${\color[rgb]{0.315209,0.728565,0.037706}p_1}$, ${\color[rgb]{0.315209,0.728565,0.037706}p_3}$, ${\color[rgb]{0.059472,0.501943,0.998465}v_1}$, ${\color[rgb]{0.918231,0.469102,0.038229}\rho}$, and ${\color[rgb]{0.599997,0.600015,0.600005}h}$. ${\color[rgb]{0.028509,0.250925,0.501969}[7]}$
#
# {\color{RubineRed}
#
# Now we apply the steady flow momentum equation between stations 2 and 3. There is an extra force term since the plate exerts a force on the fluid in the control volume
#
# \begin{equation*}
# \begin{split}
# p_2 4 h - p_3 4h + F & = \rho v_3^2 4h - \rho v_2^2 3 h \\
# \Rightarrow F & = -\rho 12 v_1^2 h + p_3 4 h - p_2 4 h \\
# \Rightarrow F & = \rho 3 v_1^2 4h - p_3 4h + \left(p_1 + 9 \rho v_1^2 \right) 4 h \\
# \Rightarrow F & = -4h \left(p_1 - p_3 + 12 \rho v_1^2 \right).
# \end{split}
# \end{equation*}
#
# Note the sign above depends on how you define $F$; in the above it is positive along the horizontal direction. If the sign for the force is incorrect, that is still acceptable for full marks.
#
# }
#
# \end{enumerate}

# %% [markdown]
# ### Problem 4
# Please clarify whether the entire statement is true or false. You are **not** required to justify your answers for statements.
#
# \begin{enumerate}
# \item[a.] Control volumes and system boundaries are very important concepts when studying fluids. Mass can cross a system boundary, however, energy in the form of work or heat cannot. ${\color[rgb]{0.028509,0.250925,0.501969}[1]}$ {\color{RubineRed} False.}
#
# \item[b.] Using the forces and stresses acting on a fluid blob, and using the definition of the material (or substantial) derivative, we can derive both the incompressible Euler and incompressible Navier Stokes equations. The difference between the two equations are the shear terms (only present in the latter). ${\color[rgb]{0.028509,0.250925,0.501969}[1]}$ {\color{RubineRed} True.}
#
# \item[c.] When studying losses in pipes, we came across the Hagen-Poiseuille equation that describes the pressure loss as a function of bulk volumetric flow rate, pipe length, pipe diameter, and fluid viscosity. ${\color[rgb]{0.028509,0.250925,0.501969}[1]}$ {\color{RubineRed} True.}
#
# \item[d.] The rate of change of altitute $A$ given an airplane's velocity ${\color[rgb]{0.059472,0.501943,0.998465}\boldsymbol{v}}$ may be expressed as ${\color[rgb]{0.059472,0.501943,0.998465}\boldsymbol{v}} \cdot \nabla A$. ${\color[rgb]{0.028509,0.250925,0.501969}[1]}$ {\color{RubineRed} True.}
#
# \item[e.] Intensive thermodynamic properties depend on the size of the system. Volume is an example. ${\color[rgb]{0.028509,0.250925,0.501969}[1]}$ {\color{RubineRed} False.}
#
# \item[f.] In the first law, a negative work term (i.e., ${\color[rgb]{0.334690,0.296180,0.998454}Q} - \left(-{\color[rgb]{0.562040,0.190215,0.568721}W} \right) = {\color[rgb]{1.000000,0.869732,0.000000}\Delta E}$) indicates that the work is transferred to the system from the surroundings. ${\color[rgb]{0.028509,0.250925,0.501969}[1]}$ {\color{RubineRed} True.}
#
# \item[g.] For ideal gases, enthalpy is a function of both temperature and pressure, while for real gases it is only a function of temperature. ${\color[rgb]{0.028509,0.250925,0.501969}[1]}$ {\color{RubineRed} False.}
#
# \end{enumerate}

# %% [raw]
# ### Problem 2
# Within the compressor of a modern turbofan engine, the stagnation temperature and stagnation pressure within the main gas path are found to be ${\color[rgb]{0.164799,0.878862,0.723179}500 \; K}$ and ${\color[rgb]{0.315209,0.728565,0.037706}13 \; atmospheres}$. The static pressure here is measured to be ${\color[rgb]{0.315209,0.728565,0.037706}10 \; atmospheres}$. What is the velocity of the gas? You may assume the heat capacity ratio, $\gamma=1.4$ and a specific gas constant value of $R=287 \; J/(K \cdot kg)$. *Hint*: Assume the flow is isentropic. ${\color[rgb]{0.028509,0.250925,0.501969}[8]}$

# %% [markdown]
# {\color{RubineRed}
#
# The solution to this problem can be obtained either via the tables or via a direct calculation. First, note that the relationship between the static and stagnation pressures permits us to work out the Mach number, i.e.,
#
# \begin{equation*}
# \begin{split}
# \frac{p_{0}}{p} & = \left( 1 + \frac{\left( \gamma - 1 \right)}{2} M^2 \right)^{\frac{\gamma}{\gamma - 1}} \\
# \frac{13}{10} & = \left( 1 + \frac{\left( 0.4 \right)}{2} M^2 \right)^{\frac{1.4}{0.4}}
# \end{split}
# \end{equation*}
#
# which leads to $M = 0.624$. To work out the velocity, we need to determine the speed of sound, $a = \sqrt{\gamma R T}$ where $T$ is the static temperature (this step is very important--using the stagnation temperature here is wrong!). Using the isentropic flow relations, we have
#
# \begin{equation*}
# \begin{split}
# \frac{p_0}{p} = \frac{13}{10}  & = \left( \frac{T_0}{T} \right)^{\gamma / (\gamma - 1 )} \\
# & = \left( \frac{500}{T} \right)^{1.4 / 0.4}
# \end{split}
# \end{equation*}
#
# which implies that $T=463.89 \; K$. This yields $a = \sqrt{1.4 \times 287 \times 463.89} = 431.73 \; m/s$. The velocity is then given by $v = M a = 0.624 \times 431.73 = 269.4 \; m/s$.
# }
